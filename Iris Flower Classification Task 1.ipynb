# %% [markdown]
# # Dattasai Danta | Data Science Intern | Oasis Infobyte | #Task 1

# %% [markdown]
# # <font color = red> **IRIS FLOWER CLASSIFICATION** </font>

# %%
#import libraries
# import pandas seaborn matplotlib numpy

# import pandas library and make it as pd:
import pandas as pd
#import numerical python library and make it as np
import numpy as np
#import seaborn library and make it as sns
import seaborn as sns
#import pyplot from matplotlib library and make it as plt:
import matplotlib.pyplot as plt
# inorder to surpress the warning import filterwarnings:
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# load Iris Dataset
df = pd.read_csv('Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# # head --> first five rows
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#tail --> last five rows
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
# drop Id column:
df = df.drop(columns = ['Id'])

# %%
# to display stats about data:
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
# values Counts
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
# checking Null Values:
df.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# `interpretation:` There is no null values present in the dataset.

# %%
# to display information of the dataset::
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Exploratory Data Analysis:

# %%
sns.pairplot(data=df)
plt.show()

# %%
df.skew()
# Out:
# SepalLengthCm    0.314911
# SepalWidthCm     0.334053
# PetalLengthCm   -0.274464
# PetalWidthCm    -0.104997
# dtype: float64

# %%
# 
df['SepalLengthCm'].hist()
# display the plot:
plt.show()

# %% [markdown]
# `interpretation:` The distribution of Sepallength slightly right skewed.

# %%
df['SepalWidthCm'].hist()
# display the plot:
plt.show()

# %% [markdown]
# `interpretation:` The distribution of Sepalwidth slightly right skewed.

# %%
df['PetalLengthCm'].hist()
# display the plot:
plt.show()

# %% [markdown]
# `interpretation:` The distribution of Petallength slightly left skewed.

# %%
df['PetalWidthCm'].hist()
# display the plot:
plt.show()

# %% [markdown]
# `interpretation:` The distribution of Petalwidth slightly left skewed.

# %%
# Scatter Plot:
colors = ['red','orange','blue']
species = ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
    x = df[df['Species']==species[i]]
    plt.scatter(x['SepalLengthCm'],x['SepalWidthCm'], c= colors[i], label=species[i])
# Set the Label of x- axis :
plt.xlabel('Sepal Length')
# Set the Label of y- axis :
plt.ylabel('Sepal Width')
# add the agenda:
plt.legend()
# Display the Plot:
plt.show()

# %%
for i in range(3):
    x = df[df['Species']==species[i]]
    plt.scatter(x['PetalLengthCm'],x['PetalWidthCm'], c= colors[i], label=species[i])
# Set the Label of x- axis :
plt.xlabel('Petal Length')
# Set the Label of y- axis :
plt.ylabel('Petal Width')
# add the agenda:
plt.legend()
# display the plot:
plt.show()

# %%
for i in range(3):
    x = df[df['Species']==species[i]]
    plt.scatter(x['SepalLengthCm'],x['PetalLengthCm'], c= colors[i], label=species[i])
# Set the Label of x- axis :
plt.xlabel('Sepal Length')
# Set the Label of y- axis :
plt.ylabel('Petal Length')
# add the agenda:
plt.legend()
# display the plot:
plt.show()

# %%
for i in range(3):
    x = df[df['Species']==species[i]]
    plt.scatter(x['SepalWidthCm'],x['PetalWidthCm'], c= colors[i], label=species[i])
# Set the Label of x- axis :
plt.xlabel('Sepal Width')
# Set the Label of y- axis :
plt.ylabel('Petal Width')
# add the agenda
plt.legend()
# display the plot:
plt.show()

# %%
# correlation
df.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
# correlation:
corr =df.corr()
fig, ax = plt.subplots(figsize=(5,4))
sns.heatmap(corr, annot=True, ax=ax, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# `INTERPRETATION` SepalLengthCm and PetalLengthCm,
# SepalLengthCm and PetalWidthCm,
# PetalLengthCm and PetalWidthCm these are the strong positive correlation.

# %% [markdown]
# # Label Encoder
# In machine learning, we usually deal with datasets which contains multiple labels in one or more than one columns. These labels can be in the form of words or numbers. label encoding refers to converting the lebels into numeric form so as to convert it into the machine-readable form.

# %%
# LabelEncoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
df['Species'] = le.fit_transform(df['Species'])
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
# value counts of Species
df['Species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: Species, dtype: int64

# %% [markdown]
# # Model Training

# %%
# we need to split the data for training and testing:
from sklearn.model_selection import train_test_split
# train- 70
# test - 30
X = df.drop(columns=['Species'])
Y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size = 0.30,random_state=42)

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# model training:
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
# print metric to get performance:
print('Accuracy: ', model.score(x_test, y_test)*100)
# Out:
# Accuracy:  100.0

# %%
# KNN k- nearest neighbours
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
print('Accuracy: ', model.score(x_test,y_test)*100)
# Out:
# Accuracy:  100.0

# %%
# decision tree:
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print('Accuracy: ',model.score(x_test,y_test)*100)
# Out:
# Accuracy:  100.0

# %%
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
y_pred = knn.predict(x_test)

# %%
y_pred = le.inverse_transform(y_pred)
y_test = le.inverse_transform(y_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_pred)
confusion = confusion_matrix(y_test, y_pred)

# %%
print(f"Accuracy: {accuracy:.2f}")
# Out:
# Accuracy: 1.00

# %%
print("Confusion Matrix:")
print(confusion)
# Out:
# Confusion Matrix:
# [[19  0  0]
#  [ 0 13  0]
#  [ 0  0 13]]

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print(classification_report(y_pred,y_test))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        19
# Iris-versicolor       1.00      1.00      1.00        13
#  Iris-virginica       1.00      1.00      1.00        13
#
#        accuracy                           1.00        45
#       macro avg       1.00      1.00      1.00        45
#    weighted avg       1.00      1.00      1.00        45
