# %% [markdown]
# # Dattasai Danta | Data Science Intern | Oasis Infobyte | #Task 2

# %% [markdown]
# # <font color = red> **UNEMPLOYMENT ANALYSIS WITH PYTHON** </font>

# %%
# import libraries:
# import numpy library as np
import numpy as np

# import pandas library as pd
import pandas as pd

# import seaborn library as sns
import seaborn as sns

# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# feature warnings:
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# load unemployement rate in india data:
df = pd.read_csv('Unemployment_Rate_upto_11_2020.csv')
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
# head --> first five rows
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
# tail --> last five rows
df.tail()
# Out:
#           Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 262  West Bengal   30-06-2020          M                              7.29
# 263  West Bengal   31-07-2020          M                              6.83
# 264  West Bengal   31-08-2020          M                             14.87
# 265  West Bengal   30-09-2020          M                              9.35
# 266  West Bengal   31-10-2020          M                              9.98
#
#       Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 262             30726310                                     40.39     East
# 263             35372506                                     46.17     East
# 264             33298644                                     47.48     East
# 265             35707239                                     47.73     East
# 266             33962549                                     45.63     East
#
#      longitude  latitude
# 262    22.9868    87.855
# ...

# %%
# shows shape of the dataset
df.shape
# Out:
# (267, 9)

# %% [markdown]
# `INTERPRETATION:` There are 267 rows and 9 columns.

# %%
# information of the dataset:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df.info
# Out:
# <bound method DataFrame.info of              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
# data types by each column
df.dtypes
# Out:
# Region                                       object
#  Date                                        object
#  Frequency                                   object
#  Estimated Unemployment Rate (%)            float64
#  Estimated Employed                           int64
#  Estimated Labour Participation Rate (%)    float64
# Region.1                                     object
# longitude                                   float64
# latitude                                    float64
# dtype: object

# %%
# Describe:
df.describe(include='object')
# Out:
#                 Region         Date  Frequency Region.1
# count              267          267        267      267
# unique              27           10          1        5
# top     Andhra Pradesh   31-03-2020          M    North
# freq                10           27        267       79

# %%
# check null values:
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %% [markdown]
# `interpretation:` There is no null values present in the dataset.

# %%
# sum of null values:
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# `interpretation:` There is no null values present in the dataset.

# %%
# check duplicate values:
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 262    False
# 263    False
# 264    False
# 265    False
# 266    False
# Length: 267, dtype: bool

# %% [markdown]
# `interpretation:` There is no duplicate values present in the dataset.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# `interpretation:` There is no duplicate values present in the dataset.

# %%
df.columns=['States','Date','Frequency','Estimated Unemployment Rate','Estimated Employed','Estimation Labour Participation Rate','Region','longitude','latitude']

# %%
df.head(20)
# Out:
#             States         Date Frequency  Estimated Unemployment Rate  \
# 0   Andhra Pradesh   31-01-2020         M                         5.48
# 1   Andhra Pradesh   29-02-2020         M                         5.83
# 2   Andhra Pradesh   31-03-2020         M                         5.79
# 3   Andhra Pradesh   30-04-2020         M                        20.51
# 4   Andhra Pradesh   31-05-2020         M                        17.43
# 5   Andhra Pradesh   30-06-2020         M                         3.31
# 6   Andhra Pradesh   31-07-2020         M                         8.34
# 7   Andhra Pradesh   31-08-2020         M                         6.96
# 8   Andhra Pradesh   30-09-2020         M                         6.40
# 9   Andhra Pradesh   31-10-2020         M                         6.59
# 10           Assam   31-01-2020         M                         4.66
# 11           Assam   29-02-2020         M                         4.41
# ...

# %%
df.drop(columns='Frequency',inplace=True)

# %%
df['Region'].value_counts()
# Out:
# North        79
# South        60
# West         50
# East         40
# Northeast    38
# Name: Region, dtype: int64

# %%
sns.countplot(x='Region',data=df)
plt.title('India Unemployment')
plt.show()

# %%
df['Date'].value_counts()
# Out:
#  31-03-2020    27
#  31-05-2020    27
#  30-06-2020    27
#  31-07-2020    27
#  31-08-2020    27
#  30-09-2020    27
#  31-10-2020    27
#  31-01-2020    26
#  29-02-2020    26
#  30-04-2020    26
# Name: Date, dtype: int64

# %%
df['Date'].unique()
# Out:
# array([' 31-01-2020', ' 29-02-2020', ' 31-03-2020', ' 30-04-2020',
#        ' 31-05-2020', ' 30-06-2020', ' 31-07-2020', ' 31-08-2020',
#        ' 30-09-2020', ' 31-10-2020'], dtype=object)

# %%
df
# Out:
#              States         Date  Estimated Unemployment Rate  \
# 0    Andhra Pradesh   31-01-2020                         5.48
# 1    Andhra Pradesh   29-02-2020                         5.83
# 2    Andhra Pradesh   31-03-2020                         5.79
# 3    Andhra Pradesh   30-04-2020                        20.51
# 4    Andhra Pradesh   31-05-2020                        17.43
# ..              ...          ...                          ...
# 262     West Bengal   30-06-2020                         7.29
# 263     West Bengal   31-07-2020                         6.83
# 264     West Bengal   31-08-2020                        14.87
# 265     West Bengal   30-09-2020                         9.35
# 266     West Bengal   31-10-2020                         9.98
#
#      Estimated Employed  Estimation Labour Participation Rate Region  \
# 0              16635535                                 41.02  South
# 1              16545652                                 40.90  South
# ...

# %%
df['States'].value_counts()
# Out:
# Andhra Pradesh      10
# Assam               10
# Uttarakhand         10
# Uttar Pradesh       10
# Tripura             10
# Telangana           10
# Tamil Nadu          10
# Rajasthan           10
# Punjab              10
# Puducherry          10
# Odisha              10
# Meghalaya           10
# Maharashtra         10
# Madhya Pradesh      10
# Kerala              10
# Karnataka           10
# Jharkhand           10
# Himachal Pradesh    10
# Haryana             10
# Gujarat             10
# Goa                 10
# Delhi               10
# Chhattisgarh        10
# Bihar               10
# West Bengal         10
# Jammu & Kashmir      9
# Sikkim               8
# Name: States, dtype: int64

# %%
# correlation:
corr = df.corr()
corr
# Out:
#                                       Estimated Unemployment Rate  \
# Estimated Unemployment Rate                              1.000000
# Estimated Employed                                      -0.245176
# Estimation Labour Participation Rate                    -0.073540
# longitude                                                0.149976
# latitude                                                -0.023976
#
#                                       Estimated Employed  \
# Estimated Unemployment Rate                    -0.245176
# Estimated Employed                              1.000000
# Estimation Labour Participation Rate           -0.047948
# longitude                                      -0.113664
# latitude                                       -0.119321
#
#                                       Estimation Labour Participation Rate  \
# Estimated Unemployment Rate                                      -0.073540
# ...

# %%
# set the plot size:

fig, ax = plt.subplots(figsize = (10, 7))

# plot a heapmap for the correlation matrix
# annot : print values in each cell
# linewidths : specify width of the line and specifying the plot
# vmin minimum value of the variable
# vmax maximum value of the variable
# cmap: colour code for the plot
# fmt : set the decimal place of the annot

sns.heatmap(corr, annot = True, linewidths = 0.95,
           cmap = 'copper', fmt = '.2g')
# display the plot:
plt.show()

# %%
# pairplor:
sns.pairplot(df)
plt.show()

# %% [markdown]
# # Estimated Employed:

# %%
# Assuming you have a DataFrame named 'df' with 'States' and 'Estimated Employed' columns
sum_employees_by_region = df.groupby('Region')['Estimated Employed'].sum().reset_index()

# Now, 'sum_employees_by_state' contains the sum of employees for each state
print(sum_employees_by_region)
# Out:
#       Region  Estimated Employed
# 0       East           784094676
# 1      North          1032726546
# 2  Northeast           137450010
# 3      South           842435360
# 4       West           931175636

# %% [markdown]
# `Interpretation:` North region has highest estimated employees during covid-19 pandamic.

# %%
x = df[['Region', 'Estimated Employed']].groupby('Region').sum()
x.plot(kind='pie', autopct='%1.1f%%', subplots=True, figsize=(15, 7), title='Estimated Employed by percentage')
plt.axis('equal')  # This line ensures that the pie chart is circular.
plt.show()

# %% [markdown]
# `Interpretation:` North region has highest percentage during covid-19 pandamic.

# %%
# Sort the DataFrame by the 'Estimated Employed' column in ascending order
sum_employees_by_region_sorted = sum_employees_by_region.sort_values(by='Estimated Employed')

plt.figure(figsize=(12, 6))
plt.bar(sum_employees_by_region_sorted['Region'], sum_employees_by_region_sorted['Estimated Employed'])
plt.title("Sum of Employees by region (Ascending Order)")
plt.xlabel('Region')
plt.ylabel('Sum of Employees')
plt.xticks(rotation=65)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Assuming you have a DataFrame named 'df' with 'States' and 'Estimated Employed' columns
sum_employees_by_state = df.groupby('States')['Estimated Employed'].sum().reset_index()

# Now, 'sum_employees_by_state' contains the sum of employees for each state
print(sum_employees_by_state)
# Out:
#               States  Estimated Employed
# 0     Andhra Pradesh           154254800
# 1              Assam           108102755
# 2              Bihar           236068280
# 3       Chhattisgarh            84213492
# 4              Delhi            46328219
# 5                Goa             4423748
# 6            Gujarat           227307461
# 7            Haryana            68440590
# 8   Himachal Pradesh            20338849
# 9    Jammu & Kashmir            29790285
# 10         Jharkhand            87706424
# 11         Karnataka           216240176
# 12            Kerala            85967949
# 13    Madhya Pradesh           223183353
# 14       Maharashtra           392047582
# 15         Meghalaya            13498153
# 16            Odisha           127268329
# 17        Puducherry             3652629
# 18            Punjab            87830342
# 19         Rajasthan           197317522
# 20            Sikkim             1876186
# 21        Tamil Nadu           219878981
# ...

# %% [markdown]
# `Interpretation:` State wise total estimated employees

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'sum_employees_by_state' with 'States' and 'Estimated Employed' columns

# Sort the DataFrame by the 'Estimated Employed' column in ascending order
sum_employees_by_state_sorted = sum_employees_by_state.sort_values(by='Estimated Employed')

plt.figure(figsize=(12, 6))
plt.bar(sum_employees_by_state_sorted['States'], sum_employees_by_state_sorted['Estimated Employed'])
plt.title("Sum of Employees by State (Ascending Order)")
plt.xlabel('State')
plt.ylabel('Sum of Employees')
plt.xticks(rotation=65)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# `Interpretation:` Uttarpradesh, Maharastra, West Bengal these are top3 estimated employees by state wise visualize clearly.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'sum_employees_by_state' with 'States' and 'Estimated Employed' columns

plt.figure(figsize=(12, 6))
plt.bar(sum_employees_by_state['States'], sum_employees_by_state['Estimated Employed'].sort_values().index)
plt.title("Sum of Employees by State")
plt.xlabel('State')
plt.ylabel('Sum of Employees')
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability
plt.show()

# %%
plt.figure(figsize=(18,14))
sns.histplot(x='Estimated Employed', hue='States', data=df, bins=20)

# add axes:
plt.title("Histogram of Estimated Employed by State")
plt.xlabel('Estimated Employed')
plt.ylabel('Frequency')

# display the plot:
plt.show()

# %% [markdown]
# # Labour Participation rate:

# %%
x = df[['Region', 'Estimation Labour Participation Rate']].groupby('Region').sum()
x.plot(kind='pie', autopct='%1.1f%%', subplots=True, figsize=(15, 7), title='Labour Participation Rate by Region')
plt.axis('equal')  # This line ensures that the pie chart is circular.
plt.show()

# %% [markdown]
# `Interpretation:` North Region has most effected labour participation rate (%)

# %%
# average Labour Participation rate by state wise:

sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))
order = df.groupby('States')['Estimation Labour Participation Rate'].mean().sort_values().index
sns.barplot(x='States', y='Estimation Labour Participation Rate', data=df, order=order)

# add axes
plt.title("Average Labour Participation Rate")
plt.xlabel('States')
plt.ylabel('Estimation Labour Participation Rate')

plt.xticks(rotation=65)  # Rotate x-axis labels for better readability
# display the plot:
plt.show()

# %% [markdown]
# `Interpretation:` Meghalaya, Tripura, Telangana are most effected labour participation rate

# %% [markdown]
# # Estimated Unemployment Rate:

# %%
x = df[['Region', 'Estimated Unemployment Rate']].groupby('Region').sum()
x.plot(kind='pie', autopct='%1.1f%%', subplots=True, figsize=(15, 7), title='Unemployment Rate by Region')

# This line ensures that the pie chart is circular.
plt.axis('equal') 

# display the plot:
plt.show()

# %% [markdown]
# `Interpretation:` North region has highly unemployed during covid-19

# %%
# Average Unemployment rate by region

sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))
order = df.groupby('Region')['Estimated Unemployment Rate'].mean().sort_values().index
sns.barplot(x='Region', y='Estimated Unemployment Rate', data=df, order=order)

# add axes
plt.title("Average Unemployment Rate by Region")
plt.xlabel('Region')
plt.ylabel('Estimated Unemployment Rate')

 # Rotate x-axis labels for better readability
plt.xticks(rotation=65)  # Rotate x-axis labels for better readability

# display the plot:
plt.show()

# %% [markdown]
# `Interpretation:` North region has highly unemployed during covid-19

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='States',y='Estimated Unemployment Rate',data=df)
plt.xticks(rotation=65)  # Rotate x-axis labels for better readability
plt.show()

# %%
# average Unemployment rate state wise:

sns.set(style="whitegrid")
plt.figure(figsize=(18, 6))
order = df.groupby('States')['Estimated Unemployment Rate'].mean().sort_values().index
sns.barplot(x='States', y='Estimated Unemployment Rate', data=df, order=order)

# add axes
plt.title("Average Unemployment Rate by States")
plt.xlabel('States')
plt.ylabel('Estimated Unemployment Rate')

plt.xticks(rotation=65)  # Rotate x-axis labels for better readability
# display the plot:
plt.show()

# %% [markdown]
# `Interpretation:` The most effected states in India during covid-19 were:
#         Haryana, Tripura, Jharkhand, Bihar, Delhi, Puduchery, Jammu & Kashmir, Himachal Pradesh, Rajasthan
